# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
df = pd.read_excel(r"C:\Users\dell\Machine Learning\Python Practice\Python General Questions\Pandas\Sample - Superstore.xls",sheet_name='Orders')
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
#Sorting by values
df.sort_values('Sales',ascending=True).head()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 4101    4102  US-2017-102288 2017-06-19 2017-06-23  Standard Class
# 9292    9293  CA-2017-124114 2017-03-02 2017-03-02        Same Day
# 8658    8659  CA-2016-168361 2016-06-21 2016-06-25  Standard Class
# 4711    4712  CA-2014-112403 2014-03-31 2014-03-31        Same Day
# 2106    2107  US-2014-152723 2014-09-26 2014-09-26        Same Day
#
#      Customer ID     Customer Name    Segment        Country          City  \
# 4101    ZC-21910  Zuschuss Carroll   Consumer  United States       Houston
# 9292    RS-19765    Roland Schwarz  Corporate  United States          Waco
# 8658    KB-16600       Ken Brennan  Corporate  United States       Chicago
# 4711    JO-15280     Jas O'Carroll   Consumer  United States  Philadelphia
# 2106    HG-14965     Henry Goldwyn  Corporate  United States      Mesquite
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
#Sorting by Index
df.sort_index(ascending=False).head()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#Reindexing 
df.reset_index(drop=True).head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.pivot_table(index='Region',values=['Sales'],aggfunc='sum')
# Out:
#                Sales
# Region
# Central  501239.8908
# East     678781.2400
# South    391721.9050
# West     725457.8245

# %%
#Dropping
df.drop(columns=['Region','Sales']).head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.nlargest(2,'Sales')
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317 2014-03-18 2014-03-23  Standard Class
# 6826    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  ...  \
# 2697    SM-20320   Sean Miller  Home Office  United States  Jacksonville  ...
# 6826    TC-20980  Tamara Chand    Corporate  United States     Lafayette  ...
#
#      Postal Code   Region       Product ID    Category Sub-Category  \
# 2697       32216    South  TEC-MA-10002412  Technology     Machines
# 6826       47905  Central  TEC-CO-10004722  Technology      Copiers
#
#                                            Product Name     Sales  Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48         6
# 6826              Canon imageCLASS 2200 Advanced Copier  17499.95         5
#
#       Discount     Profit
# 2697       0.5 -1811.0784
# 6826       0.0  8399.9760
#
# ...

# %%
df[['Sales']]
# Out:
#          Sales
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# 4      22.3680
# ...        ...
# 9989   25.2480
# 9990   91.9600
# 9991  258.5760
# 9992   29.6000
# 9993  243.1600
#
# [9994 rows x 1 columns]

# %%
df.loc[:,['Sales','Region']]
# Out:
#          Sales Region
# 0     261.9600  South
# 1     731.9400  South
# 2      14.6200   West
# 3     957.5775  South
# 4      22.3680  South
# ...        ...    ...
# 9989   25.2480  South
# 9990   91.9600   West
# 9991  258.5760   West
# 9992   29.6000   West
# 9993  243.1600   West
#
# [9994 rows x 2 columns]

# %%
df.iloc[2:4,[0,2,4]]
# Out:
#    Row ID Order Date       Ship Mode
# 2       3 2016-06-12    Second Class
# 3       4 2015-10-11  Standard Class

# %%
df.query('Sales>30').head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 3   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 5  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
# 7  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
# ...

# %% [markdown]
# ### Merge Two Data Frame

# %%
df = pd.read_excel(r"C:\Users\dell\Machine Learning\Python Practice\Python General Questions\Pandas\Sample - Superstore.xls",sheet_name='Orders')
df2 = pd.read_excel(r"C:\Users\dell\Machine Learning\Python Practice\Python General Questions\Pandas\Sample - Superstore.xls",sheet_name='Returns')

pd.merge(left=df,right=df2,how='left',on='Order ID')
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### Concatenate DataFrame

# %%
df3 = df.sample(5)
pd.concat([df,df3],axis=0,ignore_index=True)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9994    2087  CA-2016-140501 2016-06-23 2016-06-28  Standard Class
# 9995    7224  CA-2016-109953 2016-07-14 2016-07-18  Standard Class
# 9996    4531  CA-2016-118759 2016-11-14 2016-11-17     First Class
# 9997    2568  CA-2017-123967 2017-11-01 2017-11-03    Second Class
# 9998    8225  CA-2016-104633 2016-06-12 2016-06-16  Standard Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# 0       CG-12520      Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.describe(include='int')
# Out:
#             Row ID   Postal Code     Quantity
# count  9994.000000   9994.000000  9994.000000
# mean   4997.500000  55190.379428     3.789574
# std    2885.163629  32063.693350     2.225110
# min       1.000000   1040.000000     1.000000
# 25%    2499.250000  23223.000000     2.000000
# 50%    4997.500000  56430.500000     3.000000
# 75%    7495.750000  90008.000000     5.000000
# max    9994.000000  99301.000000    14.000000

# %%
df.describe(include='O')
# Out:
#               Order ID       Ship Mode Customer ID  Customer Name   Segment  \
# count             9994            9994        9994           9994      9994
# unique            5009               4         793            793         3
# top     CA-2017-100111  Standard Class    WB-21850  William Brown  Consumer
# freq                14            5968          37             37      5191
#
#               Country           City       State Region       Product ID  \
# count            9994           9994        9994   9994             9994
# unique              1            531          49      4             1862
# top     United States  New York City  California   West  OFF-PA-10001970
# freq             9994            915        2001   3203               19
#
#                Category Sub-Category     Product Name
# count              9994         9994             9994
# unique                3           17             1850
# top     Office Supplies      Binders  Staple envelope
# ...

# %% [markdown]
# ### Mathematics Function

# %%
df['Sales'].max()
# Out:
# 22638.48

# %%
df['Sales'].min()
# Out:
# 0.44399999999999995

# %%
df['Sales'].mean()
# Out:
# 229.8580008304938

# %%
df['Sales'].std()
# Out:
# 623.2451005086818

# %%
df['Sales'].median()
# Out:
# 54.489999999999995

# %%
df['Sales'].var()
# Out:
# 388434.45530807687

# %%
df['Sales'].quantile(0.25)
# Out:
# 17.28

# %%
df['Sales'].quantile([0.25,0.75])
# Out:
# 0.25     17.28
# 0.75    209.94
# Name: Sales, dtype: float64

# %%
df['New Field'] = df['Sales'].apply(lambda x: 'Good' if x <30 else 'Better' if x <50 else 'Best')
df.sample(4)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 7200    7201  CA-2016-104276 2016-11-27 2016-12-03  Standard Class
# 1514    1515  CA-2017-112809 2017-08-18 2017-08-22  Standard Class
# 6792    6793  CA-2014-141005 2014-08-15 2014-08-18     First Class
# 3122    3123  CA-2015-121720 2015-06-11 2015-06-12     First Class
#
#      Customer ID         Customer Name    Segment        Country  \
# 7200    HF-14995       Herbert Flentye   Consumer  United States
# 1514    RA-19915     Russell Applegate   Consumer  United States
# 6792    CS-12355  Christine Sundaresam   Consumer  United States
# 3122    JE-15610               Jim Epp  Corporate  United States
#
#                  City  ...   Region       Product ID         Category  \
# 7200  Fort Lauderdale  ...    South  TEC-PH-10001944       Technology
# 1514           Dallas  ...  Central  OFF-BI-10001636  Office Supplies
# 6792        Fairfield  ...     East  OFF-BI-10001989  Office Supplies
# ...

# %%
df.corr()
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity    -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# Discount     0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df['Sales'].fillna(df['Sales'].mean())
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
df.dropna(axis=0,how='any')
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### Group By Clause

# %%
df.groupby(['Region','State']).sum()[['Sales','Profit']]
# Out:
#                                     Sales      Profit
# Region  State
# Central Illinois               80166.1010 -12607.8870
#         Indiana                53555.3600  18382.9363
#         Iowa                    4579.7600   1183.8119
#         Kansas                  2914.3100    836.4435
#         Michigan               76269.6140  24463.1876
#         Minnesota              29863.1500  10823.1874
#         Missouri               22205.1500   6436.2105
#         Nebraska                7464.9300   2037.0942
#         North Dakota             919.9100    230.1497
#         Oklahoma               19683.3900   4853.9560
#         South Dakota            1315.5600    394.8283
#         Texas                 170188.0458 -25729.3563
#         Wisconsin              32114.6100   8401.8004
# East    Connecticut            13384.3570   3511.4918
#         Delaware               27451.0690   9977.3748
#         District of Columbia    2865.0200   1059.5893
# ...

# %%
df.groupby(['Region','State']).sum()[['Sales']]
# Out:
#                                     Sales
# Region  State
# Central Illinois               80166.1010
#         Indiana                53555.3600
#         Iowa                    4579.7600
#         Kansas                  2914.3100
#         Michigan               76269.6140
#         Minnesota              29863.1500
#         Missouri               22205.1500
#         Nebraska                7464.9300
#         North Dakota             919.9100
#         Oklahoma               19683.3900
#         South Dakota            1315.5600
#         Texas                 170188.0458
#         Wisconsin              32114.6100
# East    Connecticut            13384.3570
#         Delaware               27451.0690
#         District of Columbia    2865.0200
#         Maine                   1270.5300
#         Maryland               23705.5230
#         Massachusetts          28634.4340
#         New Hampshire           7292.5240
#         New Jersey             35764.3120
# ...

# %% [markdown]
# ### Graph with Pandas

# %%
df.plot.scatter(x='Sales',y='Region')
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Region'>

# %%
df.plot(x='Sales',y='Profit')
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
df['Profit'].plot.hist(bins=40)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df['Region'].nunique()
# Out:
# 4

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df.rename(columns={'y':'Year'})
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...
