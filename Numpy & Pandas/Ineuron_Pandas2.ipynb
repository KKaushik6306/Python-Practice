# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')   
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
# PassengerId    156 non-null int64
# Survived       156 non-null int64
# Pclass         156 non-null int64
# Name           156 non-null object
# Sex            156 non-null object
# Age            126 non-null float64
# SibSp          156 non-null int64
# Parch          156 non-null int64
# Ticket         156 non-null object
# Fare           156 non-null float64
# Cabin          31 non-null object
# Embarked       155 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %% [markdown]
# # Getting description of categorical data

# %% [markdown]
# ## 1st Way

# %%
df[['Name','Sex','Cabin','Embarked']].describe()
# Out:
#                                 Name   Sex Cabin Embarked
# count                            156   156    31      155
# unique                           156     2    28        3
# top     Nye, Mrs. (Elizabeth Ramell)  male   D26        S
# freq                               1   100     2      110

# %% [markdown]
# ## 2nd Way

# %%
df.dtypes =='object'
a = df.dtypes[df.dtypes=='object'].index
a
df[a].describe()
# Out:
#                                 Name   Sex  Ticket Cabin Embarked
# count                            156   156     156    31      155
# unique                           156     2     145    28        3
# top     Nye, Mrs. (Elizabeth Ramell)  male  237736   D26        S
# freq                               1   100       2     2      110

# %%
for i in a:
    print(i)
# Out:
# Name
# Sex
# Ticket
# Cabin
# Embarked

# %%
(df.dtypes =='int64')|(df.dtypes =='object')
# Out:
# PassengerId     True
# Survived        True
# Pclass          True
# Name            True
# Sex             True
# Age            False
# SibSp           True
# Parch           True
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
a = df.dtypes[df.dtypes =='object']
a
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
a[0:4]
# Out:
# Name      object
# Sex       object
# Ticket    object
# Cabin     object
# dtype: object

# %%
a[1]
# Out:
# dtype('O')

# %%
a['Name']
# Out:
# dtype('O')

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes =='object'
a = df.dtypes[df.dtypes=='object'].index
a
df[a].describe()
# Out:
#                                   Name   Sex      Ticket Cabin Embarked
# count                              156   156         156    31      155
# unique                             156     2         145    28        3
# top     Gustafsson, Mr. Anders Vilhelm  male  W./C. 6608   D26        S
# freq                                 1   100           2     2      110

# %%
df.dtypes =='int64'
a = df.dtypes[df.dtypes=='int64'].index
a
df[a].describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean     78.500000    0.346154    2.423077    0.615385    0.397436
# std      45.177428    0.477275    0.795459    1.056235    0.870146
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%      39.750000    0.000000    2.000000    0.000000    0.000000
# 50%      78.500000    0.000000    3.000000    0.000000    0.000000
# 75%     117.250000    1.000000    3.000000    1.000000    0.000000
# max     156.000000    1.000000    3.000000    5.000000    5.000000

# %%
a = df.dtypes[df.dtypes=='int64']
a
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# SibSp          int64
# Parch          int64
# dtype: object

# %%
df[df.dtypes[df.dtypes=='int64'].index].describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean     78.500000    0.346154    2.423077    0.615385    0.397436
# std      45.177428    0.477275    0.795459    1.056235    0.870146
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%      39.750000    0.000000    2.000000    0.000000    0.000000
# 50%      78.500000    0.000000    3.000000    0.000000    0.000000
# 75%     117.250000    1.000000    3.000000    1.000000    0.000000
# max     156.000000    1.000000    3.000000    5.000000    5.000000

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#                                   Name   Sex      Ticket Cabin Embarked
# count                              156   156         156    31      155
# unique                             156     2         145    28        3
# top     Gustafsson, Mr. Anders Vilhelm  male  W./C. 6608   D26        S
# freq                                 1   100           2     2      110

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Column wise Manipulation

# %%
s=df['Name']
s[0:100]
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
#                             ...
# 95                          Shorney, Mr. Charles Joseph
# 96                            Goldschmidt, Mr. George B
# 97                      Greenfield, Mr. William Bertram
# 98                 Doling, Mrs. John T (Ada Julia Bone)
# 99                                    Kantor, Mr. Sinai
# Name: Name, Length: 100, dtype: object

# %%
s[100:0] #Direction issue due to which we are getting blank values
# Out:
# Series([], Name: Name, dtype: object)

# %%
s[100:0:-1]
# Out:
# 100                              Petranec, Miss. Matilda
# 99                                     Kantor, Mr. Sinai
# 98                  Doling, Mrs. John T (Ada Julia Bone)
# 97                       Greenfield, Mr. William Bertram
# 96                             Goldschmidt, Mr. George B
#                              ...
# 5                                       Moran, Mr. James
# 4                               Allen, Mr. William Henry
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2                                 Heikkinen, Miss. Laina
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# Name: Name, Length: 100, dtype: object

# %%
s[0::4]
# Out:
# 0                                Braund, Mr. Owen Harris
# 4                               Allen, Mr. William Henry
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 12                        Saundercock, Mr. William Henry
# 16                                  Rice, Master. Eugene
# 20                                  Fynney, Mr. Joseph J
# 24                         Palsson, Miss. Torborg Danira
# 28                         O'Dwyer, Miss. Ellen "Nellie"
# 32                              Glynn, Miss. Mary Agatha
# 36                                      Mamee, Mr. Hanna
# 40        Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 44                         Devaney, Miss. Margaret Delia
# 48                                   Samaan, Mr. Youssef
# 52              Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 56                                     Rugg, Miss. Emily
# 60                                 Sirayanian, Mr. Orsen
# ...

# %% [markdown]
# # Sorting Series

# %%
df['Name'][100:150:2].sort_values()
# Out:
# 146         Andersson, Mr. August Edvard ("Wennerstrom")
# 144                           Andrew, Mr. Edgardo Samuel
# 114                                Attalah, Miss. Malake
# 112                               Barton, Mr. David John
# 118                             Baxter, Mr. Quigg Edmond
# 140                        Boulos, Mrs. Joseph (Sultana)
# 116                                 Connors, Mr. Patrick
# 130                                 Drazenoic, Mr. Jozef
# 104                       Gustafsson, Mr. Anders Vilhelm
# 142    Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 120                          Hickman, Mr. Stanley George
# 126                                  McMahon, Mr. Martin
# 122                                 Nasser, Mr. Nicholas
# 148             Navratil, Mr. Michel ("Louis M Hoffman")
# 136                         Newsom, Miss. Helen Monypeny
# 138                                  Osen, Mr. Olaf Elon
# ...

# %%
sorted(df['Name'])[100:150:2]
# Out:
# ['Novel, Mr. Mansouer',
#  'Nysten, Miss. Anna Sofia',
#  'O\'Dwyer, Miss. Ellen "Nellie"',
#  'Osen, Mr. Olaf Elon',
#  'Palsson, Master. Gosta Leonard',
#  'Panula, Master. Juha Niilo',
#  'Pekoniemi, Mr. Edvard',
#  'Petranec, Miss. Matilda',
#  'Porter, Mr. Walter Chamberlain',
#  'Rice, Master. Eugene',
#  'Robins, Mrs. Alexander A (Grace Charity Laury)',
#  'Rugg, Miss. Emily',
#  'Samaan, Mr. Youssef',
#  'Saundercock, Mr. William Henry',
#  'Shorney, Mr. Charles Joseph',
#  'Skoog, Master. Harald',
#  'Sloper, Mr. William Thompson',
#  'Spencer, Mrs. William Augustus (Marie Eugenie)',
#  'Stewart, Mr. Albert A',
#  'Turpin, Mr. William John Robert',
#  'Uruchurtu, Don. Manuel E',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Waelens, Mr. Achille',
#  'Weisz, Mrs. Leopold (Mathilde Francoise Pede)',
#  'Wheadon, Mr. Edward H']

# %% [markdown]
# # Homework

# %%
df = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')   
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 151            113776
# 152        A.5. 11206
# 153          A/5. 851
# 154         Fa 265302
# 155          PC 17597
#
# [156 rows x 1 columns]

# %%
df[['Fare','Pclass']]
# Out:
#         Fare  Pclass
# 0     7.2500       3
# 1    71.2833       1
# 2     7.9250       3
# 3    53.1000       1
# 4     8.0500       3
# ..       ...     ...
# 151  66.6000       1
# 152   8.0500       3
# 153  14.5000       3
# 154   7.3125       3
# 155  61.3792       1
#
# [156 rows x 2 columns]

# %%
df[['Survived','Pclass']].sort_values('Survived')
# Out:
#      Survived  Pclass
# 0           0       3
# 110         0       1
# 108         0       3
# 105         0       3
# 104         0       3
# ..        ...     ...
# 56          1       2
# 23          1       1
# 22          1       3
# 109         1       3
# 65          1       3
#
# [156 rows x 2 columns]

# %%
df.loc[df['Name'].str.startswith('S')]
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 12            13         0       3
# 23            24         1       1
# 31            32         1       1
# 48            49         0       3
# 60            61         0       3
# 63            64         0       3
# 64            65         0       1
# 76            77         0       3
# 81            82         1       3
# 87            88         0       3
# 95            96         0       3
# 106          107         1       3
# 134          135         0       2
#
#                                                Name     Sex   Age  SibSp  \
# 10                  Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 12                   Saundercock, Mr. William Henry    male  20.0      0
# 23                     Sloper, Mr. William Thompson    male  28.0      0
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ...

# %%
df.loc[df['Name'].str.contains('S[a-z]')]
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 12            13         0       3
# 23            24         1       1
# 25            26         1       3
# 31            32         1       1
# 43            44         1       2
# 48            49         0       3
# 52            53         1       1
# 60            61         0       3
# 63            64         0       3
# 64            65         0       1
# 70            71         0       2
# 75            76         0       3
# 76            77         0       3
# 81            82         1       3
# 87            88         0       3
# 95            96         0       3
# 99           100         0       2
# 105          106         0       3
# 106          107         1       3
# 120          121         0       2
# 123          124         1       2
# 134          135         0       2
# 140          141         0       3
# 141          142         1       3
# ...

# %%
a = df['Name']
for i in a:
    if i[0]=='S':
        print(i)
# Out:
# Sandstrom, Miss. Marguerite Rut
# Saundercock, Mr. William Henry
# Sloper, Mr. William Thompson
# Spencer, Mrs. William Augustus (Marie Eugenie)
# Samaan, Mr. Youssef
# Sirayanian, Mr. Orsen
# Skoog, Master. Harald
# Stewart, Mr. Albert A
# Staneff, Mr. Ivan
# Sheerlinck, Mr. Jan Baptist
# Slocovski, Mr. Selman Francis
# Shorney, Mr. Charles Joseph
# Salkjelsvik, Miss. Anna Kristine
# Sobey, Mr. Samuel James Hayden

# %% [markdown]
# # Adding New Columns

# %%
df['New Columne'] = 0
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['New Column2'] = df['Name']
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # To find out insights about Categorical data

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df['Name'])
# Out:
# [Braund, Mr. Owen Harris, Cumings, Mrs. John Bradley (Florence Briggs Th..., Heikkinen, Miss. Laina, Futrelle, Mrs. Jacques Heath (Lily May Peel), Allen, Mr. William Henry, ..., Pears, Mrs. Thomas (Edith Wearne), Meo, Mr. Alfonzo, van Billiard, Mr. Austin Blyler, Olsen, Mr. Ole Martin, Williams, Mr. Charles Duane]
# Length: 156
# Categories (156, object): [Ahlin, Mrs. Johan (Johanna Persdotter Larsson), Allen, Mr. William Henry, Andersson, Miss. Ellis Anna Maria, Andersson, Miss. Erna Alexandra, ..., Williams, Mr. Charles Eugene, Woolner, Mr. Hugh, Zabour, Miss. Hileni, van Billiard, Mr. Austin Blyler]

# %%
a = pd.Categorical(df['Pclass']).unique()
a
# Out:
# [3, 1, 2]
# Categories (3, int64): [3, 1, 2]

# %%
list(df['Pclass'].unique())
# Out:
# [3, 1, 2]

# %%
a = df['Pclass'].unique()
a
# Out:
# array([3, 1, 2], dtype=int64)

# %% [markdown]
# # Changing columns format

# %%
s = df['Cabin'].astype(str)
type(s[0])
# Out:
# str

# %%
for i in s:
    print(i[0])
# Out:
# n
# C
# n
# C
# n
# n
# E
# n
# n
# n
# G
# C
# n
# n
# n
# n
# n
# n
# n
# n
# n
# D
# n
# A
# n
# n
# n
# C
# n
# n
# n
# B
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# D
# n
# B
# C
# n
# n
# n
# n
# n
# B
# C
# n
# n
# n
# F
# n
# n
# n
# n
# n
# n
# n
# n
# F
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# C
# n
# n
# n
# E
# n
# n
# n
# A
# D
# n
# n
# n
# n
# D
# n
# n
# n
# n
# n
# n
# n
# C
# n
# n
# n
# n
# n
# n
# n
# B
# n
# n
# n
# n
# E
# D
# n
# n
# n
# F
# n
# n
# n
# n
# n
# n
# n
# D
# C
# n
# B
# n
# n
# n
# n
# n
# n
# n
# n
# F
# n
# n
# C
# n
# n
# n
# n

# %%
b = [i[0] for i in s]
b
# Out:
# ['n',
#  'C',
#  'n',
#  'C',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'G',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'A',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'A',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'E',
#  'D',
# ...

# %%
b = [i[0:2] for i in s]
b
# Out:
# ['na',
#  'C8',
#  'na',
#  'C1',
#  'na',
#  'na',
#  'E4',
#  'na',
#  'na',
#  'na',
#  'G6',
#  'C1',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'D5',
#  'na',
#  'A6',
#  'na',
#  'na',
#  'na',
#  'C2',
#  'na',
#  'na',
#  'na',
#  'B7',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'D3',
#  'na',
#  'B3',
#  'C5',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'B2',
#  'C8',
#  'na',
#  'na',
#  'na',
#  'F3',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'F ',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'C2',
#  'na',
#  'na',
#  'na',
#  'E3',
#  'na',
#  'na',
#  'na',
#  'A5',
#  'D1',
#  'na',
#  'na',
#  'na',
#  'na',
#  'D2',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'C1',
# ...

# %%
c = [i[0] for i in df['Name']]
c
# Out:
# ['B',
#  'C',
#  'H',
#  'F',
#  'A',
#  'M',
#  'M',
#  'P',
#  'J',
#  'N',
#  'S',
#  'B',
#  'S',
#  'A',
#  'V',
#  'H',
#  'R',
#  'W',
#  'V',
#  'M',
#  'F',
#  'B',
#  'M',
#  'S',
#  'P',
#  'A',
#  'E',
#  'F',
#  'O',
#  'T',
#  'U',
#  'S',
#  'G',
#  'W',
#  'M',
#  'H',
#  'M',
#  'C',
#  'V',
#  'N',
#  'A',
#  'T',
#  'K',
#  'L',
#  'D',
#  'R',
#  'L',
#  'O',
#  'S',
#  'A',
#  'P',
#  'N',
#  'H',
#  'F',
#  'O',
#  'W',
#  'R',
#  'N',
#  'W',
#  'G',
#  'S',
#  'I',
#  'H',
#  'S',
#  'S',
#  'M',
#  'N',
#  'C',
#  'A',
#  'K',
#  'J',
#  'G',
#  'H',
#  'C',
#  'B',
#  'M',
#  'S',
#  'M',
#  'C',
#  'D',
#  'W',
#  'S',
#  'M',
#  'C',
#  'I',
#  'B',
#  'F',
#  'S',
#  'F',
#  'C',
#  'C',
#  'A',
#  'C',
#  'D',
#  'C',
#  'S',
#  'G',
#  'G',
#  'D',
#  'K',
#  'P',
#  'P',
#  'W',
#  'J',
#  'G',
#  'M',
#  'S',
#  'M',
#  'R',
#  'M',
#  'P',
#  'Z',
#  'B',
#  'J',
#  'A',
#  'P',
#  'C',
#  'T',
#  'B',
#  'A',
#  'H',
#  'M',
#  'N',
#  'W',
#  'W',
# ...

# %%
d = pd.Categorical(df['Name'])
d
# Out:
# [Braund, Mr. Owen Harris, Cumings, Mrs. John Bradley (Florence Briggs Th..., Heikkinen, Miss. Laina, Futrelle, Mrs. Jacques Heath (Lily May Peel), Allen, Mr. William Henry, ..., Pears, Mrs. Thomas (Edith Wearne), Meo, Mr. Alfonzo, van Billiard, Mr. Austin Blyler, Olsen, Mr. Ole Martin, Williams, Mr. Charles Duane]
# Length: 156
# Categories (156, object): [Ahlin, Mrs. Johan (Johanna Persdotter Larsson), Allen, Mr. William Henry, Andersson, Miss. Ellis Anna Maria, Andersson, Miss. Erna Alexandra, ..., Williams, Mr. Charles Eugene, Woolner, Mr. Hugh, Zabour, Miss. Hileni, van Billiard, Mr. Austin Blyler]

# %%
pd.Series([i[0] for i in df['Name']]).unique()
# Out:
# array(['B', 'C', 'H', 'F', 'A', 'M', 'P', 'J', 'N', 'S', 'V', 'R', 'W',
#        'E', 'O', 'T', 'U', 'G', 'K', 'L', 'D', 'I', 'Z', 'v'],
#       dtype=object)

# %%
for i in df['Name'].unique():
    print(i[0])
# Out:
# B
# C
# H
# F
# A
# M
# M
# P
# J
# N
# S
# B
# S
# A
# V
# H
# R
# W
# V
# M
# F
# B
# M
# S
# P
# A
# E
# F
# O
# T
# U
# S
# G
# W
# M
# H
# M
# C
# V
# N
# A
# T
# K
# L
# D
# R
# L
# O
# S
# A
# P
# N
# H
# F
# O
# W
# R
# N
# W
# G
# S
# I
# H
# S
# S
# M
# N
# C
# A
# K
# J
# G
# H
# C
# B
# M
# S
# M
# C
# D
# W
# S
# M
# C
# I
# B
# F
# S
# F
# C
# C
# A
# C
# D
# C
# S
# G
# G
# D
# K
# P
# P
# W
# J
# G
# M
# S
# M
# R
# M
# P
# Z
# B
# J
# A
# P
# C
# T
# B
# A
# H
# M
# N
# W
# W
# N
# M
# M
# P
# E
# D
# C
# R
# W
# S
# R
# N
# F
# O
# G
# B
# N
# H
# B
# A
# N
# A
# F
# N
# B
# B
# P
# M
# v
# O
# W

# %%
pd.Categorical(df['Name']).unique()
# Out:
# [Braund, Mr. Owen Harris, Cumings, Mrs. John Bradley (Florence Briggs Th..., Heikkinen, Miss. Laina, Futrelle, Mrs. Jacques Heath (Lily May Peel), Allen, Mr. William Henry, ..., Pears, Mrs. Thomas (Edith Wearne), Meo, Mr. Alfonzo, van Billiard, Mr. Austin Blyler, Olsen, Mr. Ole Martin, Williams, Mr. Charles Duane]
# Length: 156
# Categories (156, object): [Braund, Mr. Owen Harris, Cumings, Mrs. John Bradley (Florence Briggs Th..., Heikkinen, Miss. Laina, Futrelle, Mrs. Jacques Heath (Lily May Peel), ..., Meo, Mr. Alfonzo, van Billiard, Mr. Austin Blyler, Olsen, Mr. Ole Martin, Williams, Mr. Charles Duane]

# %% [markdown]
# # Checking Null values

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# New Columne      0
# New Column2      0
# dtype: int64

# %% [markdown]
# # Return data frame where Age is blank

# %% [markdown]
# ## 1st Way

# %%
df[df['Age'].isnull()==True]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df[df['Age'].isnull()==True].shape
# Out:
# (30, 14)

# %% [markdown]
# ## 2nd Way

# %%
index = np.where(df['Age'].isnull()==True)

# %%
df.iloc[index]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df.loc[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df.loc[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
a = np.where(df['Fare']==df['Fare'].max())
a
# Out:
# (array([27, 88], dtype=int64),)

# %%
df.iloc[a]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked  New Columne  \
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S            0
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S            0
#
#                        New Column2
# 27  Fortune, Mr. Charles Alexander
# 88      Fortune, Miss. Mabel Helen

# %%
df.iloc[a][['Name','Sex']]
# Out:
#                               Name     Sex
# 27  Fortune, Mr. Charles Alexander    male
# 88      Fortune, Miss. Mabel Helen  female

# %%
a = df['Fare'].max()
df.loc[df['Fare']==a]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked  New Columne  \
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S            0
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S            0
#
#                        New Column2
# 27  Fortune, Mr. Charles Alexander
# 88      Fortune, Miss. Mabel Helen

# %%
df['NewColumn3'] = df['PassengerId'] + df['Pclass']
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Homework

# %%
#Q1 ) Filter out Name & Age of the person if Fare is minimum and Age is minimum
#Q2) Filter out Name If fare is minimum and age is greater than 30.

# %%
a = np.where((df['Fare']==df['Fare'].min()) & (df['Age']==df['Age'].min()))
df.iloc[a][['Name','Age']]
# Out:
# Empty DataFrame
# Columns: [Name, Age]
# Index: []

# %%
a = np.where((df['Fare']==df['Fare'].min()) | (df['Age']>30))
a
df.iloc[a]['Name']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
# 13                           Andersson, Mr. Anders Johan
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# 18     Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 20                                  Fynney, Mr. Joseph J
# 21                                 Beesley, Mr. Lawrence
# 25     Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 30                              Uruchurtu, Don. Manuel E
# 33                                 Wheadon, Mr. Edward H
# 35                        Holverson, Mr. Alexander Oskar
# 40        Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 52              Harper, Mrs. Henry Sleeper (Myna Haxtun)
# ...
