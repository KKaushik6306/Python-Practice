# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"D:\Machine Learning - Course\Sample Data Sets\Ineuron\Data\examples\ex1.csv",sep=',',header=None,index_col=False)

# %%
df.head()
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
df[0].value_counts()
# Out:
# 1    1
# 5    1
# 9    1
# a    1
# Name: 0, dtype: int64

# %%
no_cols = df.shape[0]
no_cols
# Out:
# 4

# %%
df = pd.read_csv(r"D:\Machine Learning - Course\Sample Data Sets\Ineuron\Data\examples\ex1.csv",sep=',',names=[i for i in range(len(df.columns))])

# %%
len(df.columns)
# Out:
# 7

# %%
df
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
path = "D:\Machine Learning - Course\Sample Data Sets\Ineuron\Data\examples\csv_mindex.csv"
df= pd.read_csv(path,index_col=['key1','key2'])
df
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
df['value1']
# Out:
# key1  key2
# one   a        1
#       b        3
#       c        5
#       d        7
# two   a        9
#       b       11
#       c       13
#       d       15
# Name: value1, dtype: int64

# %%
df=pd.read_csv("D:\Machine Learning - Course\Sample Data Sets\Ineuron\Data\examples\ex4.csv",skiprows=[0,2,3])
pd.isnull('a')
# Out:
# False

# %%
type(df[['a','b']])
# Out:
# pandas.core.frame.DataFrame

# %%
df =pd.read_csv("D:\Machine Learning - Course\Sample Data Sets\Ineuron\Data\examples\ex6.csv",nrows=5) 
df
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %% [markdown]
# # Reading csv file without using pandas

# %%
import csv
f=open("D:\Machine Learning - Course\Sample Data Sets\Ineuron\Data\examples\ex7.csv")
reader= csv.reader(f)
reader

# %%
for line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
with open("D:\Machine Learning - Course\Sample Data Sets\Ineuron\Data\examples\ex7.csv") as f:
    lines=list(csv.reader(f))
lines
# Out:
# [['a', 'b', 'c'], ['1', '2', '3'], ['1', '2', '3']]

# %%
a = lines[0][0]
a
# Out:
# 'a'

# %%
lines[1:]
# Out:
# [['1', '2', '3'], ['1', '2', '3']]

# %%
header,values = lines[0],lines[1:]
print(header)
print(values)
# Out:
# ['a', 'b', 'c']
# [['1', '2', '3'], ['1', '2', '3']]

# %%
l = [1,2,3,4,5]
l2 =[6,7,8,9,10]

for i in zip(l,l2):
    print(i)
# Out:
# (1, 6)
# (2, 7)
# (3, 8)
# (4, 9)
# (5, 10)

# %%
values
# Out:
# [['1', '2', '3'], ['1', '2', '3']]

# %%
dict_ = {}
for i in header:
    for x,y in zip(*values):
        dict_[i]=x,y
dict_
# Out:
# {'a': ('3', '3'), 'b': ('3', '3'), 'c': ('3', '3')}

# %%
 for i in zip(header,zip(*values)):
        print(i)
# Out:
# ('a', ('1', '1'))
# ('b', ('2', '2'))
# ('c', ('3', '3'))

# %%
for i,j in zip(header,zip(*values)):
    dict_[i]=j
dict_
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
dict_={h:v for h,v in zip(header,zip(*values))}
dict_
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
l = [1,2,5]
l2 = [3,4,5]
for i in zip(l,l2):
    print(i)
# Out:
# (1, 3)
# (2, 4)
# (5, 5)

# %% [markdown]
# # Reading JSON Data

# %% [markdown]
# ## Java Script Object Notation Format

# %%
obj = """
{"name":"wes",
"Places_Lived":["United States","Spain","Germany"],
"Pet":null,
"siblings":[{"name":"Scott","age":30,"Pets":["Zeus","Zuko"]},
            {"name":"katie","age":38,"Pets":["Sixes","Stache","Cisco"]}]}
"""

# %%
import json
result = json.loads(obj)
result
# Out:
# {'name': 'wes',
#  'Places_Lived': ['United States', 'Spain', 'Germany'],
#  'Pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'Pets': ['Zeus', 'Zuko']},
#   {'name': 'katie', 'age': 38, 'Pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
asjson = json.dumps(result)
type(asjson)
# Out:
# str

# %%
result['siblings']
# Out:
# [{'name': 'Scott', 'age': 30, 'Pets': ['Zeus', 'Zuko']},
#  {'name': 'katie', 'age': 38, 'Pets': ['Sixes', 'Stache', 'Cisco']}]

# %%
df = pd.DataFrame(result['siblings'])
df
# Out:
#     name  age                    Pets
# 0  Scott   30            [Zeus, Zuko]
# 1  katie   38  [Sixes, Stache, Cisco]

# %%
df=pd.read_json("D:\Machine Learning - Course\Sample Data Sets\Ineuron\Data\examples\example.json")
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.to_json('output.json')

# %% [markdown]
# # XML and HTML : Web Scrapping

# %%
tables = pd.read_html("file:///D:/Machine%20Learning%20-%20Course/Sample%20Data%20Sets/Ineuron/Data/examples/fdic_failed_bank_list.html")
df = tables[0]
df.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
df['Closing Date'] = pd.to_datetime(df['Closing Date'])
df['Updated Date'] = pd.to_datetime(df['Updated Date'])
df
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution Closing Date Updated Date
# 0                           Today's Bank   2016-09-23   2016-11-17
# ...

# %%
df.dtypes
# Out:
# Bank Name                        object
# City                             object
# ST                               object
# CERT                              int64
# Acquiring Institution            object
# Closing Date             datetime64[ns]
# Updated Date             datetime64[ns]
# dtype: object

# %%
df['Closing Date'].dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: Closing Date, dtype: int64

# %%
df['Closing Date'].dt.month.value_counts()
# Out:
# 7     74
# 10    58
# 4     58
# 1     49
# 2     44
# 8     41
# 5     41
# 3     39
# 9     38
# 6     36
# 11    35
# 12    34
# Name: Closing Date, dtype: int64

# %%
df['Closing Date'].dt.day.value_counts()
# Out:
# 23    31
# 30    30
# 19    30
# 20    27
# 17    23
# 16    22
# 4     21
# 18    21
# 7     20
# 15    20
# 2     20
# 14    20
# 24    19
# 28    18
# 27    18
# 22    18
# 11    18
# 21    17
# 29    16
# 26    15
# 5     15
# 13    14
# 10    14
# 8     14
# 6     14
# 25    13
# 12    10
# 9     10
# 31     8
# 1      8
# 3      3
# Name: Closing Date, dtype: int64

# %%
df['Closing Date'].dt.is_leap_year.value_counts()
# Out:
# False    460
# True      87
# Name: Closing Date, dtype: int64

# %%
df['Closing Date'].dt.week.value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Closing Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-eb928a8e0734> in <module>
# ...

# %%
df['Closing Date'].dt.weekday.value_counts()
# Out:
# 4    522
# 3     19
# 2      2
# 1      2
# 5      1
# 0      1
# Name: Closing Date, dtype: int64

# %% [markdown]
# # Binary Data Formats

# %%
df =pd.read_csv("D:\Machine Learning - Course\Sample Data Sets\Ineuron\Data\examples\ex1.csv")
df.to_pickle('frame.pickle')

# %%
df=pd.read_pickle('frame.pickle')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# Seralization - This is a process where we try to convert any file into binary format. <br>
# Deseralization - This is a process where we try to convert byte formate file to object format. <br>
#
# Some of the seralized file we are not be able to open like ORC, RC, Parque, Pickle, SAV. which is not readable. Unless and until we don't have an API.
# UTF A Coding - While doing the deseralization operation it should be able to convert it into UTF A. <br>
#
# Any ML, DL, NLP, Vision model we are going to store in some sort of binary format like .pickle, .pv, .sav, .pytorch

# %% [markdown]
# # Using HDF5 Format

# %%
frame = pd.DataFrame({'a':np.random.randn(100)})
store = pd.HDFStore('mydata.h5')
store['obj1'] = frame
store['obj1_col'] = frame['a']
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store.put('obj2',frame,format='table')
store.select('obj2',where=['index>=10 and index <=15'])
store.close()

# %%
frame.to_hdf('mydata.h5','obj3',format='table')
pd.read_hdf('mydata.h5','obj3',where = ['index<5'])
# Out:
#           a
# 0 -1.314571
# 1  0.750150
# 2  1.285892
# 3 -0.189587
# 4 -0.972804

# %% [markdown]
# # Web APIS

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp

#Just getting a response with above code, like whether this url is responsive or not.
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36303',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36303/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36303/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36303/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36303',
#   'id': 700028361,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg1NzE5MDUx',
#   'number': 36303,
#   'title': 'REGR: Fix IntegerArray unary ops regression',
#   'user': {'login': 'dsaxton',
#    'id': 2658661,
#    'node_id': 'MDQ6VXNlcjI2NTg2NjE=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/2658661?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dsaxton',
#    'html_url': 'https://github.com/dsaxton',
# ...

# %%
data = resp.json()

# %%
len(data)
# Out:
# 30

# %%
type(data)
# Out:
# list

# %%
type(data[0])
# Out:
# dict

# %%
data[0]['url']
# Out:
# 'https://api.github.com/repos/pandas-dev/pandas/issues/36303'

# %%
data[0]['id']
# Out:
# 700028361

# %%
data[0]['user']['id']
# Out:
# 2658661

# %%
df=pd.DataFrame(data,columns=['user'])
df.head()
# Out:
#                                                 user
# 0  {'login': 'dsaxton', 'id': 2658661, 'node_id':...
# 1  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 2  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 3  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 4  {'login': 'phofl', 'id': 61934744, 'node_id': ...

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
df.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'pull_request', 'body',
#        'performed_via_github_app'],
#       dtype='object')

# %%
data[0]['user']
# Out:
# {'login': 'dsaxton',
#  'id': 2658661,
#  'node_id': 'MDQ6VXNlcjI2NTg2NjE=',
#  'avatar_url': 'https://avatars0.githubusercontent.com/u/2658661?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/dsaxton',
#  'html_url': 'https://github.com/dsaxton',
#  'followers_url': 'https://api.github.com/users/dsaxton/followers',
#  'following_url': 'https://api.github.com/users/dsaxton/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/dsaxton/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/dsaxton/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/dsaxton/subscriptions',
#  'organizations_url': 'https://api.github.com/users/dsaxton/orgs',
#  'repos_url': 'https://api.github.com/users/dsaxton/repos',
#  'events_url': 'https://api.github.com/users/dsaxton/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/dsaxton/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
newdata = data[0]['user']
newdata
# Out:
# {'login': 'dsaxton',
#  'id': 2658661,
#  'node_id': 'MDQ6VXNlcjI2NTg2NjE=',
#  'avatar_url': 'https://avatars0.githubusercontent.com/u/2658661?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/dsaxton',
#  'html_url': 'https://github.com/dsaxton',
#  'followers_url': 'https://api.github.com/users/dsaxton/followers',
#  'following_url': 'https://api.github.com/users/dsaxton/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/dsaxton/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/dsaxton/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/dsaxton/subscriptions',
#  'organizations_url': 'https://api.github.com/users/dsaxton/orgs',
#  'repos_url': 'https://api.github.com/users/dsaxton/repos',
#  'events_url': 'https://api.github.com/users/dsaxton/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/dsaxton/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 30

# %%
newdata = data[1]['user']
newdata
# Out:
# {'login': 'rhshadrach',
#  'id': 45562402,
#  'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#  'avatar_url': 'https://avatars1.githubusercontent.com/u/45562402?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/rhshadrach',
#  'html_url': 'https://github.com/rhshadrach',
#  'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#  'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#  'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#  'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#  'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#  'type': 'User',
# ...

# %% [markdown]
# # Homework

# %%
maindf = pd.DataFrame()
for i in range(30):
    newdata = data[i]['user']
    if len(newdata)!=0:
        df = pd.DataFrame(newdata,index=[i])
        maindf=pd.concat([maindf,df])
maindf
# Out:
#              login        id               node_id  \
# 0          dsaxton   2658661  MDQ6VXNlcjI2NTg2NjE=
# 1       rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 2     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3            phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 4            phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 5          WillAyd    609873  MDQ6VXNlcjYwOTg3Mw==
# 6         jeschwar  36767735  MDQ6VXNlcjM2NzY3NzM1
# 7          jreback    953992  MDQ6VXNlcjk1Mzk5Mg==
# 8       cjlynch278  11150412  MDQ6VXNlcjExMTUwNDEy
# 9         koopmatt  71138455  MDQ6VXNlcjcxMTM4NDU1
# 10   galipremsagar  11664259  MDQ6VXNlcjExNjY0MjU5
# 11         mdering   1246446  MDQ6VXNlcjEyNDY0NDY=
# 12           phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 13           phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 14          prhbrt   7011110  MDQ6VXNlcjcwMTExMTA=
# 15          onshek  21543236  MDQ6VXNlcjIxNTQzMjM2
# 16        AlexeyGy  13885630  MDQ6VXNlcjEzODg1NjMw
# ...

# %%
maindf = pd.DataFrame()
for i in range(30):
    newdata = data[i]['labels']
    if len(newdata)!=0:
        subdata = newdata[0]
        df = pd.DataFrame(subdata,index=[i])
        maindf = pd.concat([maindf,df])
maindf
# Out:
#             id                   node_id  \
# 0   1817503692  MDU6TGFiZWwxODE3NTAzNjky
# 1        76811      MDU6TGFiZWw3NjgxMQ==
# 7       129350      MDU6TGFiZWwxMjkzNTA=
# 8    211029535  MDU6TGFiZWwyMTEwMjk1MzU=
# 9     32815646  MDU6TGFiZWwzMjgxNTY0Ng==
# 10      134699      MDU6TGFiZWwxMzQ2OTk=
# 11       76811      MDU6TGFiZWw3NjgxMQ==
# 13       76811      MDU6TGFiZWw3NjgxMQ==
# 14    42670965  MDU6TGFiZWw0MjY3MDk2NQ==
# 16       76812      MDU6TGFiZWw3NjgxMg==
# 18      127685      MDU6TGFiZWwxMjc2ODU=
# 20    34444536  MDU6TGFiZWwzNDQ0NDUzNg==
# 22   717120670  MDU6TGFiZWw3MTcxMjA2NzA=
# 23    13098779  MDU6TGFiZWwxMzA5ODc3OQ==
# 24   219960758  MDU6TGFiZWwyMTk5NjA3NTg=
# 27    49379259  MDU6TGFiZWw0OTM3OTI1OQ==
# 28       76811      MDU6TGFiZWw3NjgxMQ==
#
#                                                   url               name  \
# 0   https://api.github.com/repos/pandas-dev/pandas...  NA - MaskedArrays
# ...
